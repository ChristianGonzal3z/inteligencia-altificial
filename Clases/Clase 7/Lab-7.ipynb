# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Instalacion de paquetes
#
# ```python
# %pip install scikit-learn joblib pandas  matplotlib
#
#
# ```

# %% [markdown]
# ## Importar librerias
#
# ```python
# from sklearn.linear_model import LinearRegression
# import numpy as np
# from joblib import dump, load
# import sklearn.datasets as datasets
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score
# from matplotlib import pyplot as plt
# import pandas as pd
# from sklearn.svm import SVR , SVC
# from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
# from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,BaggingRegressor, ExtraTreesRegressor,RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,BaggingClassifier, ExtraTreesClassifier
# from sklearn.neural_network import MLPRegressor,MLPClassifier
# from sklearn.neighbors import KNeighborsRegressor,KNeighborsClassifier
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import accuracy_score
#
#
# ```

# %% [markdown]
# ##  Mi primer modelo
#
# ```python
# #datos de entrenamiento y prueba
#
# X = np.array([[ 1 ], [2 ], [4 ], [3 ], [ 5],[15],[10],[20],[25]])
# y = np.array([  5  ,  10 ,  20 ,  15 ,  25,  75,  50, 100, 125])
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# #crear el modelo
# modelo = LinearRegression()
#
# #entrenar el modelo
# modelo.fit(X_train, y_train)
#
# #metricas
#
# metricas=mean_squared_error(y_test, modelo.predict(X_test)), r2_score(y_test, modelo.predict(X_test)), mean_absolute_error(y_test, modelo.predict(X_test))
# print(metricas)
#
#
# #predecir
# print(modelo.predict([[30]]))
#
# #coeficientes
# print(modelo.coef_)
#
#
# ```
#
# ## Guardar el modelo
#
# ```python
# dump(modelo, 'modelo.joblib')
#
# ```
# ## Cargar el modelo
#
# ```python
#
# modelo = load('modelo.joblib')
#
# ```

# %% [markdown]
# ## Regresion
#
# ### Datasets
#
# ```python
#
# X, y=datasets.fetch_california_housing(return_X_y=True)
# #X, y=datasets.load_breast_cancer(return_X_y=True)
# X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)
#
# ```

# %% [markdown]
# ### Linear Regression
#
# ```python
# LRmodel = LinearRegression()
#
# LRmodel.fit(X_train, y_train)
#
# y_pred = LRmodel.predict(X_test)
#
# metricas = mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
# metricas
#
# ```

# %% [markdown]
# ### Support Vector Regression
#
# ```python
# SVRmodel = SVR(kernel='poly' )
# #SVRmodel = SVR(kernel='linear' )
# #SVRmodel = SVR(kernel='rbf' )
#
# SVRmodel.fit(X_train, y_train)
#
# y_pred = SVRmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
# metricas
#
# ```

# %% [markdown]
# ### Decision Tree Regression
#
# ```python
# DTmodel = DecisionTreeRegressor()
#
# DTmodel.fit(X_train, y_train)
#
# y_pred = DTmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
# metricas
#
# ```

# %% [markdown]
# ### Random Forest Regression
#
# ```python
#
# RFmodel = RandomForestRegressor()
#
# RFmodel.fit(X_train, y_train)
#
# y_pred = RFmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
# metricas
#
# ```

# %% [markdown]
# ### AdaBoost Regression
#
# ```python
#
# ABmodel = AdaBoostRegressor()
#
# ABmodel.fit(X_train, y_train)
#
# y_pred = ABmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# ### Gradient Boosting Regression
#
# ```python
#
# GBmodel = GradientBoostingRegressor()
#
# GBmodel.fit(X_train, y_train)
#
# y_pred = GBmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# ### Bagging Regression
#
# ```python
#
# BGmodel = BaggingRegressor()
#
# BGmodel.fit(X_train, y_train)
#
# y_pred = BGmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# ### Extra Trees Regression
#
# ```python
#
# ETmodel = ExtraTreesRegressor()
#
# ETmodel.fit(X_train, y_train)
#
# y_pred = ETmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# ### K-Neighbors Regression
#
# ```python
#
# KNmodel = KNeighborsRegressor()
#
# KNmodel.fit(X_train, y_train)
#
# y_pred = KNmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# ### Multi-layer Perceptron Regression
#
# ```python
#
# MLPmodel = MLPRegressor()
#
# MLPmodel.fit(X_train, y_train)
#
# y_pred = MLPmodel.predict(X_test)
#
# metricas= mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred),r2_score(y_test, y_pred)
#
# metricas
#
# ```

# %% [markdown]
# # Clasificacion

# %% [markdown]
# ## Datasets
#
# ```python
# dataset=datasets.load_iris()
# #dataset=datasets.load_digits()
# #dataset=datasets.fetch_olivetti_faces()
# #dataset=datasets.load_wine()
# #dataset=datasets.fetch_20newsgroups_vectorized(subset='all')
# #dataset=datasets.load_breast_cancer()
# #datasets.fetch_lfw_people( )
# X, y=dataset.data, dataset.target
#
# X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)
#
# ```

# %% [markdown]
# ### Support Vector Classification
#
# ```python
#
# SVCmodel = SVC(kernel='linear')
#
# #SVCmodel = SVC(kernel='poly')
#
# #SVCmodel = SVC(kernel='rbf')
#
# SVCmodel.fit(X_train, y_train)
#
# y_pred = SVCmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
# plt.colorbar()
# plt.show()
#
# ```

# %% [markdown]
# ### Decision Tree Classification
#
# ```python
#
# DTmodel = DecisionTreeClassifier()
#
# DTmodel.fit(X_train, y_train)
#
# y_pred = DTmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### Random Forest Classification
#
# ```python
#
# RFmodel = RandomForestClassifier()
#
# RFmodel.fit(X_train, y_train)
#
# y_pred = RFmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### AdaBoost Classification
#
# ```python
#
# ABmodel = AdaBoostClassifier()
#
# ABmodel.fit(X_train, y_train)
#
# y_pred = ABmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### Gradient Boosting Classification
#
# ```python
#
# GBmodel = GradientBoostingClassifier()
#
# GBmodel.fit(X_train, y_train)
#
# y_pred = GBmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### Bagging Classification
#
# ```python
#
# BGmodel = BaggingClassifier()
#
# BGmodel.fit(X_train, y_train)
#
# y_pred = BGmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### Extra Trees Classification
#
# ```python
#
# ETmodel = ExtraTreesClassifier()
#
# ETmodel.fit(X_train, y_train)
#
# y_pred = ETmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### K-Neighbors Classification
#
# ```python
#
# KNmodel = KNeighborsClassifier()
#
# KNmodel.fit(X_train, y_train)
#
# y_pred = KNmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```

# %% [markdown]
# ### Multi-layer Perceptron Classification
#
# ```python
#
# MLPmodel = MLPClassifier()
#
# MLPmodel.fit(X_train, y_train)
#
# y_pred = MLPmodel.predict(X_test)
#
# # metricas
#
# accuracy=accuracy_score(y_test, y_pred)
#
# matrix =confusion_matrix(y_test, y_pred)
#
# print(accuracy)
#
#
# plt.matshow(matrix)
#
# plt.colorbar()
#
# plt.show()
#
# ```
